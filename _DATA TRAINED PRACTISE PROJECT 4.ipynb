# %% [markdown]
# # Practice Project - 4
# Titanic Project
#
# Problem Statement:
#
# The Titanic Problem is based on the sinking of the ‘Unsinkable’ ship Titanic in early 1912. It gives you information about multiple people like their ages, sexes, sibling counts, embarkment points, and whether or not they survived the disaster.
# Based on these features, you have to predict if an arbitrary passenger on Titanic would survive the sinking or not.
#
# Note: You can find the dataset in the link below.
#
# Download Files:
#
# https://github.com/dsrscientist/dataset1/blob/master/titanic_train.csv

# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
tt=pd.read_csv('titanic_train.csv')

# %%
tt
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df=tt.drop('Survived',axis=1)

# %%
df
# Out:
#      PassengerId  Pclass                                               Name  \
# 0              1       3                            Braund, Mr. Owen Harris
# 1              2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3       3                             Heikkinen, Miss. Laina
# 3              4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5       3                           Allen, Mr. William Henry
# ..           ...     ...                                                ...
# 886          887       2                              Montvila, Rev. Juozas
# 887          888       1                       Graham, Miss. Margaret Edith
# 888          889       3           Johnston, Miss. Catherine Helen "Carrie"
# 889          890       1                              Behr, Mr. Karl Howell
# 890          891       3                                Dooley, Mr. Patrick
#
# ...

# %%
df['Survived']=pd.DataFrame(tt['Survived'])

# %%
df
# Out:
#      PassengerId  Pclass                                               Name  \
# 0              1       3                            Braund, Mr. Owen Harris
# 1              2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3       3                             Heikkinen, Miss. Laina
# 3              4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5       3                           Allen, Mr. William Henry
# ..           ...     ...                                                ...
# 886          887       2                              Montvila, Rev. Juozas
# 887          888       1                       Graham, Miss. Margaret Edith
# 888          889       3           Johnston, Miss. Catherine Helen "Carrie"
# 889          890       1                              Behr, Mr. Karl Howell
# 890          891       3                                Dooley, Mr. Patrick
#
# ...

# %%
df.columns
# Out:
# Index(['PassengerId', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Cabin', 'Embarked', 'Survived'],
#       dtype='object')

# %%
df.dtypes
# Out:
# PassengerId      int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# Survived         int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# Survived         0
# dtype: int64

# %%
df['Age']=df['Age'].fillna(np.mean(df['Age']))

# %%
df.drop('Cabin',axis=1,inplace=True)

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       2
# Survived       0
# dtype: int64

# %%
df.dtypes
# Out:
# PassengerId      int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Embarked        object
# Survived         int64
# dtype: object

# %%
import sklearn
from sklearn.preprocessing import OrdinalEncoder
orden=OrdinalEncoder()
orden.fit(df)
# Out:
# OrdinalEncoder()

# %%
for i in df.columns:
    if df[i].dtypes=='object':
        df[i]=orden.fit_transform(df[i].values.reshape(-1,1))

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       2
# Survived       0
# dtype: int64

# %%
df['Embarked']=df['Embarked'].fillna(np.mean(df['Embarked']))

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# Survived       0
# dtype: int64

# %%
df.dtypes
# Out:
# PassengerId      int64
# Pclass           int64
# Name           float64
# Sex            float64
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket         float64
# Fare           float64
# Embarked       float64
# Survived         int64
# dtype: object

# %%
for i in df.columns:
    if df[i].dtypes=='float':
        df[i]=df[i].astype(int)

# %%
df.dtypes
# Out:
# PassengerId    int64
# Pclass         int64
# Name           int32
# Sex            int32
# Age            int32
# SibSp          int64
# Parch          int64
# Ticket         int32
# Fare           int32
# Embarked       int32
# Survived       int64
# dtype: object

# %%
df.describe()
# Out:
#        PassengerId      Pclass        Name         Sex         Age  \
# count   891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000    2.308642  445.000000    0.647587   29.544332
# std     257.353842    0.836071  257.353842    0.477990   13.013778
# min       1.000000    1.000000    0.000000    0.000000    0.000000
# 25%     223.500000    2.000000  222.500000    0.000000   22.000000
# 50%     446.000000    3.000000  445.000000    1.000000   29.000000
# 75%     668.500000    3.000000  667.500000    1.000000   35.000000
# max     891.000000    3.000000  890.000000    1.000000   80.000000
#
#             SibSp       Parch      Ticket        Fare    Embarked    Survived
# count  891.000000  891.000000  891.000000  891.000000  891.000000  891.000000
# mean     0.523008    0.381594  338.528620   31.785634    1.534231    0.383838
# std      1.102743    0.806057  200.850657   49.703730    0.791603    0.486592
# ...

# %%
df.corr()
# Out:
#              PassengerId    Pclass      Name       Sex       Age     SibSp  \
# PassengerId     1.000000 -0.035144 -0.038559  0.042939  0.033741 -0.057527
# Pclass         -0.035144  1.000000  0.052831  0.131900 -0.335071  0.083081
# Name           -0.038559  0.052831  1.000000  0.020314  0.053472 -0.017230
# Sex             0.042939  0.131900  0.020314  1.000000  0.082533 -0.114631
# Age             0.033741 -0.335071  0.053472  0.082533  1.000000 -0.232743
# SibSp          -0.057527  0.083081 -0.017230 -0.114631 -0.232743  1.000000
# Parch          -0.001652  0.018443 -0.049105 -0.245489 -0.176744  0.414838
# Ticket         -0.056554  0.319869  0.047348  0.059372 -0.068962  0.079461
# Fare            0.012668 -0.550553 -0.049591 -0.182331  0.094069  0.159506
# Embarked        0.013126  0.166521 -0.007661  0.112094 -0.027387  0.069568
# Survived       -0.005007 -0.338481 -0.057343 -0.543351 -0.067809 -0.035322
#
#                 Parch    Ticket      Fare  Embarked  Survived
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.pairplot(df)

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(),annot=True)
plt.show()

# %%
plt.figure(figsize=(10,10))
df.corr()['Survived'].sort_values().plot(kind='bar')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df.skew()
# Out:
# PassengerId    0.000000
# Pclass        -0.630548
# Name           0.000000
# Sex           -0.618921
# Age            0.459563
# SibSp          3.695352
# Parch          2.749117
# Ticket         0.000246
# Fare           4.786430
# Embarked      -1.256969
# Survived       0.478523
# dtype: float64

# %%
plt.figure(figsize=(30,30))
df.plot(kind='box',subplots=True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df.columns
# Out:
# Index(['PassengerId', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Embarked', 'Survived'],
#       dtype='object')

# %%
df['PassengerId'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
df['Pclass'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
df['Name'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
df['Sex'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
df['Age'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
df['SibSp'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
df['Parch'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
df['Ticket'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
df['Fare'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
df['Embarked'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
df['Survived'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
from scipy.stats import zscore
zscore=np.abs(zscore(df))

# %%
dfnew=df[(zscore<3).all(axis=1)]
dfnew
# Out:
#      PassengerId  Pclass  Name  Sex  Age  SibSp  Parch  Ticket  Fare  \
# 0              1       3   108    1   22      1      0     523     7
# 1              2       1   190    0   38      1      0     596    71
# 2              3       3   353    0   26      0      0     669     7
# 3              4       1   272    0   35      1      0      49    53
# 4              5       3    15    1   35      0      0     472     8
# ..           ...     ...   ...  ...  ...    ...    ...     ...   ...
# 886          887       2   548    1   27      0      0     101    13
# 887          888       1   303    0   19      0      0      14    30
# 888          889       3   413    0   29      1      2     675    23
# 889          890       1    81    1   26      0      0       8    30
# 890          891       3   220    1   32      0      0     466     7
#
#      Embarked  Survived
# 0           2         0
# 1           0         1
# 2           2         1
# 3           2         1
# ...

# %%
df.shape
# Out:
# (891, 11)

# %%
dfnew.shape
# Out:
# (820, 11)

# %%
data_loss=(891-820)/891
data_loss*100
# Out:
# 7.968574635241302

# %%
x=dfnew.iloc[:,0:-1]
y=dfnew['Survived']

# %%
x
# Out:
#      PassengerId  Pclass  Name  Sex  Age  SibSp  Parch  Ticket  Fare  Embarked
# 0              1       3   108    1   22      1      0     523     7         2
# 1              2       1   190    0   38      1      0     596    71         0
# 2              3       3   353    0   26      0      0     669     7         2
# 3              4       1   272    0   35      1      0      49    53         2
# 4              5       3    15    1   35      0      0     472     8         2
# ..           ...     ...   ...  ...  ...    ...    ...     ...   ...       ...
# 886          887       2   548    1   27      0      0     101    13         2
# 887          888       1   303    0   19      0      0      14    30         2
# 888          889       3   413    0   29      1      2     675    23         2
# 889          890       1    81    1   26      0      0       8    30         0
# 890          891       3   220    1   32      0      0     466     7         1
#
# [820 rows x 10 columns]

# %%
y
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 820, dtype: int64

# %%
x.shape
# Out:
# (820, 10)

# %%
y.shape
# Out:
# (820,)

# %%
y.value_counts()
# Out:
# 0    500
# 1    320
# Name: Survived, dtype: int64

# %%
from imblearn.over_sampling import SMOTE
smt=SMOTE()

# %%
x_train,y_train=smt.fit_resample(x,y)

# %%
x_train.value_counts()
# Out:
# PassengerId  Pclass  Name  Sex  Age  SibSp  Parch  Ticket  Fare  Embarked
# 1            3       108   1    22   1      0      523     7     2           1
# 584          3       633   0    29   0      1      230     15    0           1
# 575          3       708   1    16   0      0      520     8     2           1
# 576          3       639   1    19   0      0      420     14    2           1
# 577          2       277   0    34   0      0      143     13    2           1
#                                                                             ..
# 299          1       714   1    29   0      0      98      30    2           1
#                      850   0    33   0      0      603     113   0           1
# 301          2       419   0    31   0      0      113     12    1           1
#              3       431   0    29   0      0      513     7     1           1
# 891          3       220   1    32   0      0      466     7     1           1
# Length: 1000, dtype: int64

# %%
y_train.value_counts()
# Out:
# 0    500
# 1    500
# Name: Survived, dtype: int64

# %%
sns.countplot(y_train)
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %%
x_train
# Out:
#      PassengerId  Pclass  Name  Sex  Age  SibSp  Parch  Ticket  Fare  Embarked
# 0              1       3   108    1   22      1      0     523     7         2
# 1              2       1   190    0   38      1      0     596    71         0
# 2              3       3   353    0   26      0      0     669     7         2
# 3              4       1   272    0   35      1      0      49    53         2
# 4              5       3    15    1   35      0      0     472     8         2
# ..           ...     ...   ...  ...  ...    ...    ...     ...   ...       ...
# 995          143       2   655    0   29      0      0     179    19         0
# 996           68       3   514    0   29      0      0     255     7         0
# 997          285       1   288    0   46      0      0     586   114         1
# 998          639       1   781    0   31      0      0      75    34         0
# 999          834       3   376    1   16      0      0     340     8         2
#
# ...

# %%
y_train
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 995    1
# 996    1
# 997    1
# 998    1
# 999    1
# Name: Survived, Length: 1000, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import r2_score,accuracy_score
lr=LogisticRegression()

# %%
maxAcc=0
maxRS=0
for i in range(0,1000):
    x_train1,x_test,y_train1,y_test=train_test_split(x_train,y_train,test_size=0.20,random_state=i)
    lr.fit(x_train1,y_train1)
    predlr=lr.predict(x_test)
    score=accuracy_score(y_test,predlr)
    print('Accuracy_score: ' ,score, 'at random_state' , i)
    if score>maxAcc:
        maxAcc=score
        maxRS=i
        print('Best Accuracy_score : ' ,maxAcc*100, 'at random_state ' ,i)
# Out:
# Accuracy_score:  0.78 at random_state 0
# Best Accuracy_score :  78.0 at random_state  0
# Accuracy_score:  0.74 at random_state 1
# Accuracy_score:  0.775 at random_state 2
# Accuracy_score:  0.82 at random_state 3
# Best Accuracy_score :  82.0 at random_state  3
# Accuracy_score:  0.805 at random_state 4
# Accuracy_score:  0.82 at random_state 5
# Accuracy_score:  0.805 at random_state 6
# Accuracy_score:  0.835 at random_state 7
# Best Accuracy_score :  83.5 at random_state  7
# Accuracy_score:  0.82 at random_state 8
# Accuracy_score:  0.82 at random_state 9
# Accuracy_score:  0.825 at random_state 10
# Accuracy_score:  0.82 at random_state 11
# Accuracy_score:  0.85 at random_state 12
# Best Accuracy_score :  85.0 at random_state  12
# Accuracy_score:  0.8 at random_state 13
# Accuracy_score:  0.845 at random_state 14
# Accuracy_score:  0.81 at random_state 15
# Accuracy_score:  0.775 at random_state 16
# Accuracy_score:  0.82 at random_state 17
# ...

# %%
x_train1,x_test,y_train1,y_test=train_test_split(x_train,y_train,test_size=0.20,random_state=504)
lr.fit(x_train1,y_train1)
predlr=lr.predict(x_test)
print((accuracy_score(y_test,predlr))*100)
# Out:
# 89.0

# %%
from sklearn.model_selection import GridSearchCV

# %%
lr=LogisticRegression()
parameters={'C':[100,10,1,0.1,0.01]}
gscv=GridSearchCV(estimator=lr,param_grid=parameters)
gscv.fit(x_train1,y_train1)
# Out:
# GridSearchCV(estimator=LogisticRegression(),
#              param_grid={'C': [100, 10, 1, 0.1, 0.01]})

# %%
print(gscv.best_estimator_)
print(gscv.best_params_)
# Out:
# LogisticRegression(C=1)
# {'C': 1}

# %%
lr=LogisticRegression(C=1)
lr.fit(x_train1,y_train1)
predlr=lr.predict(x_test)
print('Accuracy_score' ,accuracy_score(y_test,predlr)*100)
# Out:
# Accuracy_score 89.0

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import GradientBoostingClassifier,AdaBoostClassifier,ExtraTreesClassifier,RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
knc=KNeighborsClassifier()
gbc=GradientBoostingClassifier()
abc=AdaBoostClassifier()
etc=ExtraTreesClassifier()
rfc=RandomForestClassifier()
dtc=DecisionTreeClassifier()
svc=SVC()

# %%
model=[knc,gbc,abc,etc,rfc,dtc,svc]
for i in model:
    i.fit(x_train1,y_train1)
    predi=i.predict(x_test)
    print('Accuracy_score of model ' , i ,'is = ' ,accuracy_score(y_test,predi)*100)
# Out:
# Accuracy_score of model  KNeighborsClassifier() is =  67.5
# Accuracy_score of model  GradientBoostingClassifier() is =  87.5
# Accuracy_score of model  AdaBoostClassifier() is =  85.0
# Accuracy_score of model  ExtraTreesClassifier() is =  88.5
# Accuracy_score of model  RandomForestClassifier() is =  89.5
# Accuracy_score of model  DecisionTreeClassifier() is =  80.5
# Accuracy_score of model  SVC() is =  68.5

# %%
models=[gbc,abc,etc,rfc]
parameters={'n_estimators':[50,100,200,300,400,500]}
for i in models:
    gscv=GridSearchCV(estimator=i,param_grid=parameters)
    gscv.fit(x_train1,y_train1)

# %%
print(gscv.best_estimator_)
print(gscv.best_params_)
# Out:
# RandomForestClassifier(n_estimators=300)
# {'n_estimators': 300}

# %%
rfc=RandomForestClassifier(n_estimators=300)
rfc.fit(x_train1,y_train1)
predrfc=rfc.predict(x_test)
print('Accuracy_score ' ,accuracy_score(y_test,predrfc)*100)
# Out:
# Accuracy_score  90.0

# %%
gbc=GradientBoostingClassifier(n_estimators=300)
gbc.fit(x_train1,y_train1)
predgbc=gbc.predict(x_test)
print('Accuracy_score ' ,accuracy_score(y_test,predgbc)*100)
# Out:
# Accuracy_score  88.0

# %%
a=np.array(y_test)
l=np.array(lr.predict(x_test))
df_trial=pd.DataFrame(data={'Actual results':a,'Predicted result':l},index=range(len(a)))
df_trial
# Out:
#      Actual results  Predicted result
# 0                 1                 1
# 1                 0                 0
# 2                 0                 1
# 3                 0                 0
# 4                 0                 0
# ..              ...               ...
# 195               1                 1
# 196               1                 1
# 197               1                 1
# 198               1                 1
# 199               0                 0
#
# [200 rows x 2 columns]

# %%
a=np.array(y_test)
r=np.array(rfc.predict(x_test))
g=np.array(gbc.predict(x_test))
df_trial1=pd.DataFrame(data={'Actual results':a,'Predicted result 1':l,'Predicted result 2':g},index=range(len(a)))
df_trial1
# Out:
#      Actual results  Predicted result 1  Predicted result 2
# 0                 1                   1                   1
# 1                 0                   0                   0
# 2                 0                   1                   1
# 3                 0                   0                   0
# 4                 0                   0                   0
# ..              ...                 ...                 ...
# 195               1                   1                   1
# 196               1                   1                   1
# 197               1                   1                   1
# 198               1                   1                   1
# 199               0                   0                   0
#
# [200 rows x 3 columns]

# %%
import pickle
filename=('titanic_survived.pkl')
pickle.dump(rfc,open(filename,'wb'))

# %%
pickle.load(open(filename,'rb'))
# Out:
# RandomForestClassifier(n_estimators=300)
